# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

sns.set_style('darkgrid')
# sns.set(style="white")

# import openpyxl
from sklearn.model_selection import train_test_split
from sklearn import linear_model
# Plot inline in notebook
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Explatory Analysis on Features

# %%
#  load data
features = pd.read_csv('Lingusitics_features.csv')

# %%
features.describe()
# Out:
#        Complexity_Score   lemma_ttr  lemma_mattr  lexical_density_tokens  \
# count        629.000000  629.000000   629.000000              629.000000
# mean          16.888712    0.403537     0.732523                0.517914
# std            3.542330    0.135082     0.053286                0.042095
# min            7.000000    0.146652     0.525325                0.370656
# 25%           15.000000    0.302326     0.705154                0.487518
# 50%           17.000000    0.374150     0.739046                0.516043
# 75%           20.000000    0.489177     0.764972                0.546099
# max           24.000000    1.000000     1.000000                0.708333
#
#        lexical_density_types  content_ttr  function_ttr  function_mattr  \
# count             629.000000   629.000000    629.000000      629.000000
# mean                0.751177     0.573918      0.239154        0.478291
# std                 0.071191     0.146862      0.133924        0.057459
# min                 0.538462     0.204545      0.059901        0.339111
# 25%                 0.702970     0.463320      0.145022        0.450000
# 50%                 0.751174     0.558621      0.210526        0.477019
# 75%                 0.805310     0.676829      0.297297        0.497857
# max                 0.889034     1.000000      1.000000        1.000000
#
#          noun_ttr    verb_ttr               ...                 WN_Zscore_FW  \
# count  629.000000  629.000000               ...                   629.000000
# mean     0.597850    0.546606               ...                    -0.597543
# std      0.159328    0.155209               ...                     0.020036
# min      0.148649    0.184524               ...                    -0.680400
# 25%      0.500000    0.433333               ...                    -0.606781
# 50%      0.575682    0.520548               ...                    -0.596450
# 75%      0.706897    0.645161               ...                    -0.586843
# max      1.000000    1.000000               ...                    -0.491000
#
#          WN_SD_FW  WN_Mean_Accuracy_FW  lsa_average_top_three_cosine  \
# count  629.000000           629.000000                    629.000000
# mean   124.940377             0.994875                      0.168166
# std      5.228184             0.001816                      0.020412
# min    102.301200             0.982500                      0.110204
# 25%    121.654524             0.994021                      0.155882
# 50%    125.234937             0.994960                      0.167364
# 75%    128.441193             0.995952                      0.178246
# max    150.560500             1.000000                      0.308889
#
#        lsa_max_similarity_cosine  lsa_average_all_cosine  aoe_inverse_average  \
# count                 629.000000              629.000000           629.000000
# mean                    0.293310                0.156104             0.349877
# std                     0.030364                0.019163             0.048542
# min                     0.203952                0.105876             0.178566
# 25%                     0.274375                0.143371             0.320305
# 50%                     0.292910                0.154948             0.353007
# 75%                     0.310541                0.167240             0.379499
# max                     0.477778                0.250319             0.496058
#
#        aoe_inverse_linear_regression_slope  aoe_index_above_threshold_40  \
# count                           629.000000                    629.000000
# mean                              1.086688                      2.268420
# std                               0.085593                      0.565112
# min                               0.875043                      0.333333
# 25%                               1.028498                      1.916201
# 50%                               1.080919                      2.309735
# 75%                               1.139594                      2.609302
# max                               1.525967                      4.187500
#
#        aoe_inflection_point_polynomial
# count                       629.000000
# mean                          4.487388
# std                           0.590423
# min                           2.069901
# 25%                           4.143529
# 50%                           4.537053
# 75%                           4.840509
# max                           6.183197
#
# [8 rows x 630 columns]
